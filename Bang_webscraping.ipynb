# %% [markdown]
# <a href="https://colab.research.google.com/github/BrendaLoznik/BigBangTheory/blob/main/Bang_webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# data source: https://bigbangtrans.wordpress.com/ : Contains 10 of the 12 seasons

# %% [markdown]
# # 1 Housekeeping

# %% [markdown]
# ### 1.1 Import libraries

# %%
#basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats
from bs4 import BeautifulSoup

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 200)

# %% [markdown]
# ### 1.2 Connect to drive

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### 1.3 Custom functions

# %%
#function to use regex to clean text
def find_between( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %% [markdown]
# # 2 Scraping

# %% [markdown]
# ### 2.1 Scrape URLs

# %%
#grab the html of a site
import requests
url = 'https://bigbangtrans.wordpress.com/series-1-episode-1-pilot-episode/'
result = requests.get(url)

# %%
#create a html file from the html request
doc = BeautifulSoup(result.text, 'html.parser')

# %%
#retrieve the htmls
htmls =doc.find_all('a')
html_strings = []
for x in htmls:
    html_strings.append(str(x))

html_strings[5:10]
# Out:
# ['<a href="https://bigbangtrans.wordpress.com/about/">About</a>',
#  '<a aria-current="page" href="https://bigbangtrans.wordpress.com/series-1-episode-1-pilot-episode/">Series 01 Episode 01 – Pilot\xa0Episode</a>',
#  '<a href="https://bigbangtrans.wordpress.com/series-1-episode-2-the-big-bran-hypothesis/">Series 01 Episode 02 – The Big Bran\xa0Hypothesis</a>',
#  '<a href="https://bigbangtrans.wordpress.com/series-1-episode-3-the-fuzzy-boots-corollary/">Series 01 Episode 03 – The Fuzzy Boots\xa0Corollary</a>',
#  '<a href="https://bigbangtrans.wordpress.com/series-1-episode-4-the-luminous-fish-effect/">Series 01 Episode 04 – The Luminous Fish\xa0Effect</a>']

# %%
#create a list of cleaned urls
cleaned_urls = []
for x in html_strings:
  cleaned_html = find_between(x, 'href="', '">Series')
  cleaned_urls.append(cleaned_html)
  cleaned_urls = [x for x in cleaned_urls if x]  #this removes empty strings from the list

cleaned_urls[0:10]
# Out:
# ['https://bigbangtrans.wordpress.com/series-1-episode-1-pilot-episode/',
#  'https://bigbangtrans.wordpress.com/series-1-episode-2-the-big-bran-hypothesis/',
#  'https://bigbangtrans.wordpress.com/series-1-episode-3-the-fuzzy-boots-corollary/',
#  'https://bigbangtrans.wordpress.com/series-1-episode-4-the-luminous-fish-effect/',
#  'https://bigbangtrans.wordpress.com/series-1-episode-5-the-hamburger-postulate/',
#  'https://bigbangtrans.wordpress.com/series-1-episode-6-the-middle-earth-paradigm/',
#  'https://bigbangtrans.wordpress.com/series-1-episode-7-the-dumpling-paradox/',
#  'https://bigbangtrans.wordpress.com/series-1-episode-8-the-grasshopper-experiment/',
#  'https://bigbangtrans.wordpress.com/series-1-episode-9-the-cooper-hofstadter-polarization/',
#  'https://bigbangtrans.wordpress.com/series-1-episode-10-the-loobenfeld-decay/']

# %% [markdown]
# ### 2.2 Season 1

# %% [markdown]
# The HTML structure of Season 1 differs from the other seasons, so I will extract them sepperately.

# %%
#grab the html of a site
import requests

season_1 =  pd.DataFrame(columns=['line', 'character_scene	', 'episode'])

season1_urls = cleaned_urls[0:18] #season 1 + first  episode of season 2, from the second episode onwards I get an error

for url in season1_urls:
  result = requests.get(url)

  #fetch the html of the url
  doc = BeautifulSoup(result.text, 'html.parser')
  #extract the episode title
  title = doc.title.string
  #print(title)

  #fined all text lines from the p classes labeled 'msonormal
  paragraphs = doc.find_all('p')

  #convert the paragraphs to strings 
  string_paragraphs = []
  for x in paragraphs:
    string_paragraphs.append(str(x))
  #print(string_paragraphs)

  #clean the paragraphs
  cleaned_paragraphs = []
  for x in string_paragraphs:
    cleaned_paragraph = find_between(x, 'Calibri;">', "</span>")
    cleaned_paragraph = cleaned_paragraph.replace('<em>', "")  #some weird strings remain that we can remove
    cleaned_paragraph = cleaned_paragraph.replace('</em>', "")
    cleaned_paragraphs.append(cleaned_paragraph )
    cleaned_paragraphs = [x for x in cleaned_paragraphs if x]  #this removes empty strings from the list
  #print(cleaned_paragraphs)

  #create df of cleaned paragraphs
  episode_df = pd.DataFrame(cleaned_paragraphs)
  episode_df.head(20)
  episode_df=  episode_df.rename(columns={0: "line"})
  episode_df['character_scene'] = episode_df['line'].str.split(":").str[0]
  episode_df['line'] = episode_df['line'].str.split(":").str[1]
  episode_df['episode'] = title


  #appends single episode df to full df
  season_1 = season_1.append(episode_df)

#a completely empty column is returned that we can drop
season_1 = season_1.drop('character_scene\t', axis=1)
season_1
# Out:
#                                                   line  \
# 0                          A corridor at a sperm bank.
# 1     So if a photon is directed through a plane wi...
# 2                           Agreed, what’s your point?
# 3     There’s no point, I just think it’s a good id...
# 4                                           Excuse me?
# ..                                                 ...
# 244   Well, it’s really not that fancy, it’s just a...
# 245   Right, but I have to have some sort of degree...
# 246                  That doesn’t matter to me at all.
# 247          So, it’s fine with you if I’m not smart.
# 248   Absolutely. (She slams the door in his face.)...
#
#                                                episode character_scene
# 0    Series 01 Episode 01 – Pilot Episode | Big Ban...           Scene
# 1    Series 01 Episode 01 – Pilot Episode | Big Ban...         Sheldon
# 2    Series 01 Episode 01 – Pilot Episode | Big Ban...         Leonard
# 3    Series 01 Episode 01 – Pilot Episode | Big Ban...         Sheldon
# 4    Series 01 Episode 01 – Pilot Episode | Big Ban...         Leonard
# ..                                                 ...             ...
# 244  Series 02 Episode 01 – The Bad Fish Paradigm |...         Leonard
# 245  Series 02 Episode 01 – The Bad Fish Paradigm |...           Penny
# 246  Series 02 Episode 01 – The Bad Fish Paradigm |...         Leonard
# 247  Series 02 Episode 01 – The Bad Fish Paradigm |...           Penny
# 248  Series 02 Episode 01 – The Bad Fish Paradigm |...         Leonard
#
# [4653 rows x 3 columns]

# %% [markdown]
# ### 2.3 season 2-9

# %%
#grab the html of a site
import requests

seasons_except7 =  pd.DataFrame(columns=['line', 'character_scene	', 'episode'])

#create list of urls
season2to6_url = cleaned_urls[18:135]
season8to9_url = cleaned_urls[159:-24]
seasons_except7_url = season2to6_url + season8to9_url  #create a list of seasons 2, 3, 4, 5, 6, 8 and 9

for url in seasons_except7_url:
  result = requests.get(url)

  #fetch the html of the url
  doc = BeautifulSoup(result.text, 'html.parser')
  #extract the episode title
  title = doc.title.string
  #print(title)

  #fined all text lines from the p classes labeled 'msonormal
  paragraphs = doc.find_all('p')

  #convert the paragraphs to strings 
  string_paragraphs = []
  for x in paragraphs:
    string_paragraphs.append(str(x))
  #print(string_paragraphs)

  #clean the paragraphs
  cleaned_paragraphs = []
  for x in string_paragraphs:
    cleaned_paragraph = find_between(x, '<p>', "</p>")  #if you use > and <, the scene is somehow lost
    cleaned_paragraph = cleaned_paragraph.replace('<em>', "")  #some weird strings remain that we can remove
    cleaned_paragraph = cleaned_paragraph.replace('</em>', "")
    cleaned_paragraphs.append(cleaned_paragraph )
    cleaned_paragraphs = [x for x in cleaned_paragraphs if x]  #this removes empty strings from the list
  #print(cleaned_paragraphs)

  #create df of cleaned paragraphs
  episode_df = pd.DataFrame(cleaned_paragraphs)
  episode_df=  episode_df.rename(columns={0: "line"})
  episode_df['character_scene'] = episode_df['line'].str.split(":").str[0]
  episode_df['line'] = episode_df['line'].str.split(":").str[1]
  episode_df['episode'] = title


  #appends single episode df to full df
  seasons_except7 = seasons_except7.append(episode_df)

#a completely empty column is returned that we can drop
seasons_except7 = seasons_except7.drop('character_scene\t', axis=1)
seasons_except7
# Out:
#                                                   line  \
# 0     The building entrance lobby. The guys enter. ...
# 1                         Worst Renaissance Fair ever.
# 2                           Please let it go, Sheldon.
# 3     It was rife with historical inaccuracies. For...
# 4                                   You’re nitpicking.
# ..                                                 ...
# 279                          I don’t like this at all.
# 280                            I don’t like it either.
# 281                          Really? ‘Cause I love it.
# 282  //www.paypal.com/cgi-bin/webscr?cmd=_s-xclick&...
# 283  //wordpress.com/?ref=footer_website" rel="nofo...
#
#                                                episode character_scene
# 0    Series 02 Episode 02 – The Codpiece Topology |...           Scene
# 1    Series 02 Episode 02 – The Codpiece Topology |...         Sheldon
# 2    Series 02 Episode 02 – The Codpiece Topology |...         Leonard
# 3    Series 02 Episode 02 – The Codpiece Topology |...         Sheldon
# 4    Series 02 Episode 02 – The Codpiece Topology |...         Leonard
# ..                                                 ...             ...
# 279  Series 09 Episode 24 – The Convergence Converg...         Sheldon
# 280  Series 09 Episode 24 – The Convergence Converg...         Leonard
# 281  Series 09 Episode 24 – The Convergence Converg...           Penny
# 282  Series 09 Episode 24 – The Convergence Converg...  <a href="https
# 283  Series 09 Episode 24 – The Convergence Converg...  <a href="https
#
# [38625 rows x 3 columns]

# %% [markdown]
# ### 2.4 Season 7A

# %%
#grab the html of a site
import requests

season_7_a =  pd.DataFrame(columns=['line', 'character_scene	', 'episode'])

season_7_urls_a =   cleaned_urls[135: -81]

for url in season_7_urls_a :
  result = requests.get(url)

  #fetch the html of the url
  doc = BeautifulSoup(result.text, 'html.parser')
  #extract the episode title
  title = doc.title.string
  #print(title)

  #fined all text lines from the p classes labeled 'msonormal
  paragraphs = doc.find_all('p')

  #convert the paragraphs to strings 
  string_paragraphs = []
  for x in paragraphs:
    string_paragraphs.append(str(x))
  #print(string_paragraphs)

  #clean the paragraphs
  cleaned_paragraphs = []
  for x in string_paragraphs:
    cleaned_paragraph = find_between(x, ';">', "</")
    cleaned_paragraph = cleaned_paragraph.replace('<i>', "")
    cleaned_paragraphs.append(cleaned_paragraph )
    cleaned_paragraphs = [x for x in cleaned_paragraphs if x]  #this removes empty strings from the list
  #print(cleaned_paragraphs)

  #create df of cleaned paragraphs
  episode_df = pd.DataFrame(cleaned_paragraphs)
  episode_df=  episode_df.rename(columns={0: "line"})
  episode_df['character_scene'] = episode_df['line'].str.split(":").str[0]
  episode_df['line'] = episode_df['line'].str.split(":").str[1]
  episode_df['episode'] = title


  #appends single episode df to full df
  season_7_a = season_7_a.append(episode_df)

#a completely empty column is returned that we can drop
season_7_a = season_7_a.drop('character_scene\t', axis=1)
season_7_a
# Out:
#                                                   line  \
# 0     On the deck of a ship on the North Sea, in th...
# 1     Sheldon, it’s not a great time, what do you w...
# 2                                                  NaN
# 3                                          What is it?
# 4     Back to the Future II was in the Back to the ...
# ..                                                 ...
# 233   Hmm. It never occurred to me to pick a favour...
# 234                                Well, give it a go.
# 235   I can’t answer that without collecting additi...
# 236                          Additional data. You dog.
# 237   I’m not sure how listening to other nine-fing...
#
#                                                episode  \
# 0    Series 07 Episode 01 – The Hofstadter Insuffic...
# 1    Series 07 Episode 01 – The Hofstadter Insuffic...
# 2    Series 07 Episode 01 – The Hofstadter Insuffic...
# 3    Series 07 Episode 01 – The Hofstadter Insuffic...
# 4    Series 07 Episode 01 – The Hofstadter Insuffic...
# ..                                                 ...
# 233  Series 07 Episode 15 – The Locomotive Manipula...
# 234  Series 07 Episode 15 – The Locomotive Manipula...
# 235  Series 07 Episode 15 – The Locomotive Manipula...
# 236  Series 07 Episode 15 – The Locomotive Manipula...
# 237  Series 07 Episode 15 – The Locomotive Manipula...
#
#                 character_scene
# 0                         Scene
# 1                       Leonard
# 2    Sheldon (in the apartment)
# 3                       Leonard
# 4                       Sheldon
# ..                          ...
# 233                     Sheldon
# 234                     Leonard
# 235                     Sheldon
# 236                     Leonard
# 237                     Sheldon
#
# [3585 rows x 3 columns]

# %% [markdown]
# ### 2.4 Season 7B

# %%
#grab the html of a site
import requests

season_7_b =  pd.DataFrame(columns=['line', 'character_scene	', 'episode'])

season_7_urls_b = cleaned_urls[150:159]

for url in season_7_urls_b :
  result = requests.get(url)

  #fetch the html of the url
  doc = BeautifulSoup(result.text, 'html.parser')
  #extract the episode title
  title = doc.title.string
  #print(title)

  #fined all text lines from the p classes labeled 'msonormal
  paragraphs = doc.find_all('p')

  #convert the paragraphs to strings 
  string_paragraphs = []
  for x in paragraphs:
    string_paragraphs.append(str(x))
  #print(string_paragraphs)

  #clean the paragraphs
  cleaned_paragraphs = []
  for x in string_paragraphs:
    cleaned_paragraph = find_between(x, '<p>', "</")
    cleaned_paragraph = cleaned_paragraph.replace('<em>', "")
    cleaned_paragraphs.append(cleaned_paragraph )
    cleaned_paragraphs = [x for x in cleaned_paragraphs if x]  #this removes empty strings from the list
  #print(cleaned_paragraphs)

  #create df of cleaned paragraphs
  episode_df = pd.DataFrame(cleaned_paragraphs)
  episode_df=  episode_df.rename(columns={0: "line"})
  episode_df['character_scene'] = episode_df['line'].str.split(":").str[0]
  episode_df['line'] = episode_df['line'].str.split(":").str[1]
  episode_df['episode'] = title


  #appends single episode df to full df
  season_7_b = season_7_b.append(episode_df)

#a completely empty column is returned that we can drop
season_7_b = season_7_b.drop('character_scene\t', axis=1)
season_7_b
# Out:
#                                                   line  \
# 0                                        The apartment
# 1                 I’m thinking about growing a goatee.
# 2     Oh, actually that’s a Van Dyke. A goatee is j...
# 3     Oh. Wait, then what is it if you just have ha...
# 4                               You mean a moo-stache?
# ..                                                 ...
# 267      I really think this is gonna be for the best.
# 268   Me, too. And he was able to take a sabbatical...
# 269                          How could you let him go?
# 270  //www.paypal.com/cgi-bin/webscr?cmd=_s-xclick&...
# 271  //wordpress.com/?ref=footer_website" rel="nofo...
#
#                                                episode character_scene
# 0    Series 07 Episode 16 – The Table Polarisation ...           Scene
# 1    Series 07 Episode 16 – The Table Polarisation ...          Howard
# 2    Series 07 Episode 16 – The Table Polarisation ...             Raj
# 3    Series 07 Episode 16 – The Table Polarisation ...         Leonard
# 4    Series 07 Episode 16 – The Table Polarisation ...             Raj
# ..                                                 ...             ...
# 267  Series 07 Episode 24 – The Status Quo Combusti...           Penny
# 268  Series 07 Episode 24 – The Status Quo Combusti...         Leonard
# 269  Series 07 Episode 24 – The Status Quo Combusti...             Amy
# 270  Series 07 Episode 24 – The Status Quo Combusti...  <a href="https
# 271  Series 07 Episode 24 – The Status Quo Combusti...  <a href="https
#
# [2196 rows x 3 columns]

# %% [markdown]
# ### 2.4 Season 10

# %%
#grab the html of a site
import requests

season_10 =  pd.DataFrame(columns=['line', 'character_scene	', 'episode'])

season_10_urls =  cleaned_urls[-24:]  #season 10 also has a different html structure

for url in season_10_urls:
  result = requests.get(url)

  #fetch the html of the url
  doc = BeautifulSoup(result.text, 'html.parser')
  #extract the episode title
  title = doc.title.string
  #print(title)

  #fined all text lines from the p classes labeled 'msonormal
  paragraphs = doc.find_all('p')

  #convert the paragraphs to strings 
  string_paragraphs = []
  for x in paragraphs:
    string_paragraphs.append(str(x))
  #print(string_paragraphs)

  #clean the paragraphs
  cleaned_paragraphs = []
  for x in string_paragraphs:
      cleaned_paragraph = find_between(x, 'sans-serif;"', "</")
      cleaned_paragraph = cleaned_paragraph.replace('<i>', "")
      cleaned_paragraph = cleaned_paragraph.replace('>', "")
      cleaned_paragraphs.append(cleaned_paragraph )
      cleaned_paragraphs = [x for x in cleaned_paragraphs if x]  #this removes empty strings from the list
  #print(cleaned_paragraphs)

  #create df of cleaned paragraphs
  episode_df = pd.DataFrame(cleaned_paragraphs)
  episode_df=  episode_df.rename(columns={0: "line"})
  episode_df['character_scene'] = episode_df['line'].str.split(":").str[0]
  episode_df['line'] = episode_df['line'].str.split(":").str[1]
  episode_df['episode'] = title


  #appends single episode df to full df
  season_10 = season_10.append(episode_df)

#a completely empty column is returned that we can drop
season_10 = season_10.drop('character_scene\t', axis=1)
season_10
# Out:
#                                                   line  \
# 0                                                  NaN
# 1                         Leonard and Penny’s bedroom.
# 2                                    Leonard? Leonard?
# 3                                                What?
# 4         You realize you and I could become brothers.
# ..                                                 ...
# 234   And I with you. Question, are you seeking a r...
# 235                                    What if I were?
# 236   Well, that would raise a number of problems. ...
# 237                                        Princeton.
# 238                             (Knock, knock, knock)
#
#                                                episode  \
# 0    Series 10 Episode 01 – The Conjugal Conjecture...
# 1    Series 10 Episode 01 – The Conjugal Conjecture...
# 2    Series 10 Episode 01 – The Conjugal Conjecture...
# 3    Series 10 Episode 01 – The Conjugal Conjecture...
# 4    Series 10 Episode 01 – The Conjugal Conjecture...
# ..                                                 ...
# 234  Series 10 Episode 24 – The Long Distance Disso...
# 235  Series 10 Episode 24 – The Long Distance Disso...
# 236  Series 10 Episode 24 – The Long Distance Disso...
# 237  Series 10 Episode 24 – The Long Distance Disso...
# 238  Series 10 Episode 24 – The Long Distance Disso...
#
#                            character_scene
# 0    Following a “previously on” sequence.
# 1                                    Sceme
# 2                                  Sheldon
# 3                                  Leonard
# 4                                  Sheldon
# ..                                     ...
# 234                                Sheldon
# 235                                 Ramona
# 236                                Sheldon
# 237                                  Scene
# 238                                Sheldon
#
# [5980 rows x 3 columns]

# %% [markdown]
# # 2 Scraping continues

# %% [markdown]
# I later on noticed that I miss episodes 6-1 and 6-4 in my dataset.

# %% [markdown]
# ### 3.1 Season 6-1

# %%
#grab the html of a site
import requests
url = 'https://bigbangtrans.wordpress.com/series-6-episode-01-the-date-night-variable/'
result = requests.get(url)

#create a html file from the html request
doc = BeautifulSoup(result.text, 'html.parser')

#extract the title from the html
titles = doc.find_all('title')

#first occurence of the title tag
tag = doc.title
print(tag.string)
# Out:
# Series 06 Episode 01 – The Date Night Variable | Big Bang Theory Transcripts

# %%
#find all p-tags
tags = doc.find_all('p') #print all 'p' tags

# %%
p =doc.find_all('p')
paragraphs = []
for x in p:
    paragraphs.append(str(x))

paragraphs[0:10]
# Out:
# ['<p class="western"><span style="font-size:small;">Following a “Previously on The Big Bang Theory” section</span></p>',
#  '<p class="western"><span style="font-size:small;"><em>Scene: The Comic Book Store.</em></span></p>',
#  '<p class="western"><span style="font-size:small;">Stuart: So, Howard’s really in space, huh?</span></p>',
#  '<p class="western"><span style="font-size:small;">Leonard: Mm-hmm, International Space Station. 250 miles that way.</span></p>',
#  '<p class="western"><span style="font-size:small;">Raj: Right now, Howard’s staring down at our planet like a tiny Jewish Greek god. Zeusowitz.</span></p>',
#  '<p class="western"><span style="font-size:small;">Sheldon: I must admit, I can’t help but feel a twinge of envy. He can look out the window and see the majesty of the universe unfolding before his eyes. His dim, uncomprehending eyes. It’s like a cat in an airport carrying case.</span></p>',
#  '<p class="western"><span style="font-size:small;">Leonard: You know, it’s not exactly glamorous up there. The water that the astronauts drink is made from each other’s recycled urine.</span></p>',
#  '<p class="western"><span style="font-size:small;">Stuart: Must be nice. Nobody wants anything that comes out of me.</span></p>',
#  '<p class="western"><span style="font-size:small;">Raj: I wonder what he’s doing right this very second.</span></p>',
#  '<p class="western"><span style="font-size:small;">Leonard: Mm, conducting experiments in zero gravity.</span></p>']

# %%
#nice: the function works on the list
cleaned_paragraphs = []
for x in paragraphs:
  cleaned_line = find_between(x, 'small;">', "</")
  cleaned_line = cleaned_line.replace('<em>', "")
  cleaned_paragraphs.append(cleaned_line)

cleaned_paragraphs[0:10]
# Out:
# ['Following a “Previously on The Big Bang Theory” section',
#  'Scene: The Comic Book Store.',
#  'Stuart: So, Howard’s really in space, huh?',
#  'Leonard: Mm-hmm, International Space Station. 250 miles that way.',
#  'Raj: Right now, Howard’s staring down at our planet like a tiny Jewish Greek god. Zeusowitz.',
#  'Sheldon: I must admit, I can’t help but feel a twinge of envy. He can look out the window and see the majesty of the universe unfolding before his eyes. His dim, uncomprehending eyes. It’s like a cat in an airport carrying case.',
#  'Leonard: You know, it’s not exactly glamorous up there. The water that the astronauts drink is made from each other’s recycled urine.',
#  'Stuart: Must be nice. Nobody wants anything that comes out of me.',
#  'Raj: I wonder what he’s doing right this very second.',
#  'Leonard: Mm, conducting experiments in zero gravity.']

# %%
#create df of cleaned paragraphs
epsidode_6_1 = pd.DataFrame(cleaned_paragraphs)
epsidode_6_1= epsidode_6_1.rename(columns={0: "line"})
epsidode_6_1['character_scene'] = epsidode_6_1['line'].str.split(":").str[0]
epsidode_6_1['line'] = epsidode_6_1['line'].str.split(":").str[1]

#add episode title
title = doc.title
epsidode_6_1['episode'] = title.string

epsidode_6_1.head(10)
# Out:
#                                                 line  \
# 0                                                NaN
# 1                              The Comic Book Store.
# 2                 So, Howard’s really in space, huh?
# 3   Mm-hmm, International Space Station. 250 mile...
# 4   Right now, Howard’s staring down at our plane...
# 5   I must admit, I can’t help but feel a twinge ...
# 6   You know, it’s not exactly glamorous up there...
# 7   Must be nice. Nobody wants anything that come...
# 8   I wonder what he’s doing right this very second.
# 9        Mm, conducting experiments in zero gravity.
#
#                                      character_scene  \
# 0  Following a “Previously on The Big Bang Theory...
# 1                                              Scene
# 2                                             Stuart
# 3                                            Leonard
# 4                                                Raj
# 5                                            Sheldon
# 6                                            Leonard
# 7                                             Stuart
# 8                                                Raj
# 9                                            Leonard
#
#                                              episode
# 0  Series 06 Episode 01 – The Date Night Variable...
# 1  Series 06 Episode 01 – The Date Night Variable...
# 2  Series 06 Episode 01 – The Date Night Variable...
# 3  Series 06 Episode 01 – The Date Night Variable...
# 4  Series 06 Episode 01 – The Date Night Variable...
# 5  Series 06 Episode 01 – The Date Night Variable...
# 6  Series 06 Episode 01 – The Date Night Variable...
# 7  Series 06 Episode 01 – The Date Night Variable...
# 8  Series 06 Episode 01 – The Date Night Variable...
# 9  Series 06 Episode 01 – The Date Night Variable...

# %% [markdown]
# ### 3.2 Season 6-4

# %%
#grab the html of a site
import requests
url = 'https://bigbangtrans.wordpress.com/series-6-episode-04-the-re-entry-minimization/'
result = requests.get(url)

#create a html file from the html request
doc = BeautifulSoup(result.text, 'html.parser')

#extract the title from the html
titles = doc.find_all('title')

#first occurence of the title tag
tag = doc.title
print(tag.string)
# Out:
# Series 06 Episode 04 – The Re-Entry Minimization | Big Bang Theory Transcripts

# %%
#find all p-tags
tags = doc.find_all('p') #print all 'p' tags
print(tags)
# Out:
# [<p class="western"><em>Scene: The Apartment.</em></p>, <p class="western">Raj: Howard’s capsule should be re-entering the atmosphere any minute.</p>, <p class="western">Leonard: It’ll be good to have him back.</p>, <p class="western">Raj: The Fantastic Four reunited.</p>, <p class="western">Sheldon: Yeah, you had a good run, Fake Wolowitz. We’ll remember you with nostalgic fondness, the way we do the dial-up modem, the VHS tape, or, or Leonard’s gym membership.</p>, <p class="western">Raj: We’re not kicking him out. Stuart and I have become good friends.</p>, <p class="western">Sheldon: Okay, one vote for, one vote against. Leonard, you’re the tiebreaker.</p>, <p class="western">Leonard: I don’t have a problem with Stuart. Besides, he gives us a twenty percent discount at his comic book store.</p>, <p class="western">Sheldon: Well, I don’t sell my friendship that cheaply.</p>, <p class="western">Stuart: I can go thirty.</p>, <p class="western">Sheldon: Welcome aboard, old chum.</p>, <p class="western">Raj: Okay, the NASA Web site says Howard’s final descent has begun.</p>, <p class="western">Sheldon: He left a boy, he returns a boy-sized hero.</p>, <p class="western"><em>Scene: The Soyuz Capsule. Howard is screaming.</em></p>, <p class="western">Dimitri: Loops, calm down!</p>, <p class="western">Howard <i>(singing)</i><span style="font-style:normal;">: </span>Baruch atah, Adonai, Eloheinu. Melech haolam, hamotzi. Lechem min haaretz</p>, <p class="western">Mike: What’s that?</p>, <p class="western">Howard: The Jewish prayer for eating bread! We don’t have one for falling out of space! We did it! We’re on the ground! We survived!</p>, <p class="western">Mike: That was just the parachute. We still have another six miles to go. <i>(Howard screams again)</i></p>, <p class="western"><i>Credits sequence.</i></p>, <p class="western"><em>Scene: The Airport Arrivals Hall.</em></p>, <p class="western">Bernadette: Waiting for my husband.</p>, <p class="western">Man in Suit: That’s nice.</p>, <p class="western">Bernadette: He’s coming back from outer space.</p>, <p class="western">Man in Suit: I think this flight’s coming from Houston.</p>, <p class="western">Bernadette: No, I mean, he… Never mind. There he is! Howie!</p>, <p class="western"><span style="font-style:normal;">Various others </span><i>(all at once)</i><span style="font-style:normal;">: </span>Howie! Howie!</p>, <p class="western">Howard: Whoa, thank you. Great to be back on Earth.</p>, <p class="western">Howie Mandel: Uh, I think they’re here for me, Ringo.</p>, <p class="western">Man in Suit: Mr. Mandel, I’m your driver.</p>, <p class="western">Howie Mandel: Oh, thanks. That nut job was telling everybody on the plane he’s an astronaut.</p>, <p class="western">Bernadette: I missed you so much.</p>, <p class="western">Howard: I missed you, too. Where are the guys?</p>, <p class="western">Bernadette: Oh, it’s just me.</p>, <p class="western">Howard: Oh, I get it. They’re waiting back home with a big surprise party. Don’t worry, I can act surprised. <i>(Does)</i></p>, <p class="western">Bernadette: No, I told them they could have you tomorrow night. Tonight, you belong to me. <i>(Sneezes) </i></p>, <p class="western">Howard: Gesundheit. You okay?</p>, <p class="western">Bernadette: I am now that you’re back. Come on, let’s go home so I can tear off those little pants.</p>, <p class="western">Howard: Great. Just keep in mind astronauts lose a lot of muscle tone in space, so you might have to do most of the heavy lifting.</p>, <p class="western"><em>Scene: The apartment. </em></p>, <p class="western">Sheldon: You know, I am very disappointed that I won’t be able to celebrate Howard’s accomplishment tonight.</p>, <p class="western">Amy: Me, too. But we’ll see him tomorrow.</p>, <p class="western">Sheldon: Yes, it’s just that in all the years I’ve known him, he’s never had the opportunity to receive my admiration. I was excited to see the look on his face when it finally happened.< ...

# %%
p =doc.find_all('p')
paragraphs = []
for x in p:
    paragraphs.append(str(x))

paragraphs[0:10]
# Out:
# ['<p class="western"><em>Scene: The Apartment.</em></p>',
#  '<p class="western">Raj: Howard’s capsule should be re-entering the atmosphere any minute.</p>',
#  '<p class="western">Leonard: It’ll be good to have him back.</p>',
#  '<p class="western">Raj: The Fantastic Four reunited.</p>',
#  '<p class="western">Sheldon: Yeah, you had a good run, Fake Wolowitz. We’ll remember you with nostalgic fondness, the way we do the dial-up modem, the VHS tape, or, or Leonard’s gym membership.</p>',
#  '<p class="western">Raj: We’re not kicking him out. Stuart and I have become good friends.</p>',
#  '<p class="western">Sheldon: Okay, one vote for, one vote against. Leonard, you’re the tiebreaker.</p>',
#  '<p class="western">Leonard: I don’t have a problem with Stuart. Besides, he gives us a twenty percent discount at his comic book store.</p>',
#  '<p class="western">Sheldon: Well, I don’t sell my friendship that cheaply.</p>',
#  '<p class="western">Stuart: I can go thirty.</p>']

# %%
#nice: the function works on the list
cleaned_paragraphs = []
for x in paragraphs:
  cleaned_line = find_between(x, '"western"', "</")
  cleaned_line = cleaned_line.replace('<em>', "")
  cleaned_line = cleaned_line.replace('>', "")
  cleaned_paragraphs.append(cleaned_line)

cleaned_paragraphs[0:10]
# Out:
# ['Scene: The Apartment.',
#  'Raj: Howard’s capsule should be re-entering the atmosphere any minute.',
#  'Leonard: It’ll be good to have him back.',
#  'Raj: The Fantastic Four reunited.',
#  'Sheldon: Yeah, you had a good run, Fake Wolowitz. We’ll remember you with nostalgic fondness, the way we do the dial-up modem, the VHS tape, or, or Leonard’s gym membership.',
#  'Raj: We’re not kicking him out. Stuart and I have become good friends.',
#  'Sheldon: Okay, one vote for, one vote against. Leonard, you’re the tiebreaker.',
#  'Leonard: I don’t have a problem with Stuart. Besides, he gives us a twenty percent discount at his comic book store.',
#  'Sheldon: Well, I don’t sell my friendship that cheaply.',
#  'Stuart: I can go thirty.']

# %%
#create df of cleaned paragraphs
epsidode_6_4 = pd.DataFrame(cleaned_paragraphs)
epsidode_6_4= epsidode_6_4.rename(columns={0: "line"})
epsidode_6_4['character_scene'] = epsidode_6_4['line'].str.split(":").str[0]
epsidode_6_4['line'] = epsidode_6_4['line'].str.split(":").str[1]

#add episode title
title = doc.title
epsidode_6_4['episode'] = title.string

epsidode_6_4.head(10)
# Out:
#                                                 line character_scene  \
# 0                                     The Apartment.           Scene
# 1   Howard’s capsule should be re-entering the at...             Raj
# 2                    It’ll be good to have him back.         Leonard
# 3                       The Fantastic Four reunited.             Raj
# 4   Yeah, you had a good run, Fake Wolowitz. We’l...         Sheldon
# 5   We’re not kicking him out. Stuart and I have ...             Raj
# 6   Okay, one vote for, one vote against. Leonard...         Sheldon
# 7   I don’t have a problem with Stuart. Besides, ...         Leonard
# 8     Well, I don’t sell my friendship that cheaply.         Sheldon
# 9                                   I can go thirty.          Stuart
#
#                                              episode
# 0  Series 06 Episode 04 – The Re-Entry Minimizati...
# 1  Series 06 Episode 04 – The Re-Entry Minimizati...
# 2  Series 06 Episode 04 – The Re-Entry Minimizati...
# 3  Series 06 Episode 04 – The Re-Entry Minimizati...
# 4  Series 06 Episode 04 – The Re-Entry Minimizati...
# 5  Series 06 Episode 04 – The Re-Entry Minimizati...
# 6  Series 06 Episode 04 – The Re-Entry Minimizati...
# 7  Series 06 Episode 04 – The Re-Entry Minimizati...
# 8  Series 06 Episode 04 – The Re-Entry Minimizati...
# 9  Series 06 Episode 04 – The Re-Entry Minimizati...

# %% [markdown]
# # 4 Append and save

# %%
episodes = season_1.append(seasons_except7)  #append season 2, 3, 4, 5, 6, 8, 9
episodes = episodes.append(epsidode_6_1) #appends episode 6-1
episodes = episodes.append(epsidode_6_4)
episodes = episodes.append(season_7_a)
episodes = episodes.append(season_7_b) #append season 7b
episodes = episodes.append(season_10) #append season 10
episodes
# Out:
#                                                   line  \
# 0                          A corridor at a sperm bank.
# 1     So if a photon is directed through a plane wi...
# 2                           Agreed, what’s your point?
# 3     There’s no point, I just think it’s a good id...
# 4                                           Excuse me?
# ..                                                 ...
# 234   And I with you. Question, are you seeking a r...
# 235                                    What if I were?
# 236   Well, that would raise a number of problems. ...
# 237                                        Princeton.
# 238                             (Knock, knock, knock)
#
#                                                episode character_scene
# 0    Series 01 Episode 01 – Pilot Episode | Big Ban...           Scene
# 1    Series 01 Episode 01 – Pilot Episode | Big Ban...         Sheldon
# 2    Series 01 Episode 01 – Pilot Episode | Big Ban...         Leonard
# 3    Series 01 Episode 01 – Pilot Episode | Big Ban...         Sheldon
# 4    Series 01 Episode 01 – Pilot Episode | Big Ban...         Leonard
# ..                                                 ...             ...
# 234  Series 10 Episode 24 – The Long Distance Disso...         Sheldon
# 235  Series 10 Episode 24 – The Long Distance Disso...          Ramona
# 236  Series 10 Episode 24 – The Long Distance Disso...         Sheldon
# 237  Series 10 Episode 24 – The Long Distance Disso...           Scene
# 238  Series 10 Episode 24 – The Long Distance Disso...         Sheldon
#
# [55529 rows x 3 columns]

# %%
#save  dataframe 
episodes.to_csv("raw_episodes2.csv", index=False, sep = '=')
